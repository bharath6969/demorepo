# %%
print("hello world")

# %%
# %run ./include/setup

# %%
full_name

# %%
# %fs

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files =dbutils.fs.ls('/databricks-datasets')
print(files)
display(files)
